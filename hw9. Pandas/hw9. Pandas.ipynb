# %%
import pandas as pd

# %%
data = pd.read_csv('ratings.csv')
data.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
movies = data[['movieId','rating']]

filters = movies[ (movies['movieId']) & (movies['rating']==5.0) ]

filters['movieId'].value_counts().head(1)
# Out:
# 2571    25482
# Name: movieId, dtype: int64

# %%
countries = pd.read_csv('power.csv')
countries.head()
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1

# %%
data_f = countries [
    ((countries['country'] == 'Lithuania') | 
    (countries['country'] == 'Estonia' ) | 
    (countries['country'] == 'Latvia')) &
    ((countries['category'] == 4)|
    (countries['category'] == 12)|
    (countries['category'] == 21))&
    ((countries['year'] == 2005) |
     (countries['year'] == 2006) |
     (countries['year'] == 2007) |
     (countries['year'] == 2008) |
     (countries['year'] == 2009) |
     (countries['year'] == 2010)) &
     ((countries['quantity']>= 0))
]

sum(data_f['quantity'])
# Out:
# 240580.0

# %%
pd.read_html('https://www.finanz.ru/valyuty/v-realnom-vremeni',  encoding='utf-8') [1]
# Out:
#     Unnamed: 0              Рубль  Предложение  Спрос  Предыдущее закрытие  \
# 0          NaN            GBP/RUB      1002194      -              1016203
# 1          NaN            EUR/RUB       910350      -               927685
# 2          NaN            USD/RUB       776295      -               790142
# 3          NaN            JPY/RUB        07359      -                07477
# 4          NaN            CNY/RUB       114314      -               115916
# 5          NaN            CHF/RUB       843069      -               858945
# 6          NaN               Евро  Предложение  Спрос  Предыдущее закрытие
# 7          NaN            EUR/USD        11727      -                11742
# 8          NaN            EUR/GBP        09084      -                09130
# 9          NaN            EUR/JPY      1237200      -              1240600
# 10         NaN            EUR/CHF        10799      -                10802
# ...
